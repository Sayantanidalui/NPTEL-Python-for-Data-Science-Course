# %%
import numpy as np

# %%
#Q1- which object doestn't support indexing :- set

# %%
#Q2- to join "data" and "science" with a (-) between them :- "-".join(["data","science"]) & "data"+"-"+"science"

# %%
#Q3
a=np.array([[1,2],[3,4]])
b=np.array([[5,6],[7,8]])
c=np.dot(a,b)
print(c)
# Out:
# [[19 22]
#  [43 50]]

# %%
#Q4
a=np.arange(10)
b=a[1:5]
b[0]=10
print(a)
# Out:
# [ 0 10  2  3  4  5  6  7  8  9]

# %%
#Q5
s={1,2,4,5}
l=[]

for i in range(len(s)):
    l+=[1+i]
print(l)
# Out:
# [1, 2, 3, 4]

# %%
#Q6
A={1,'two',3.0,3,27.5,'four',5}
B={27.5,10}
print(A | B)
# Out:
# {1, 3.0, 5, 'four', 10, 27.5, 'two'}

# %%
#Q7
t1=(1,2,"tuple",4)
t2=(5,6,7)

# %%
x=t2[t1[1]]
print(x)
# Out:
# 7

# %%
t3=t1+t2
print(t3)
# Out:
# (1, 2, 'tuple', 4, 5, 6, 7)

# %%
t3=(t1,t2)
print(t3)
# Out:
# ((1, 2, 'tuple', 4), (5, 6, 7))

# %%
t3=(list(t1),list(t2))
print(t3)
# Out:
# ([1, 2, 'tuple', 4], [5, 6, 7])

# %%
#Q8
d={1:"python",2:[1,2,3]}
d[2].append(4)
print(d)
# Out:
# {1: 'python', 2: [1, 2, 3, 4]}

# %%
d["one"]=1

# %%
d.update({'one':2})

# %%
print(d)
# Out:
# {1: 'python', 2: [1, 2, 3, 4], 'one': 2}

# %%
#Q9 which data type is immutable:- tuple

# %%
#Q10
student={'name':'jane','age':25,'courses':['Math','statistics']}
student.update({'age':26,'phone':'123-456'})
print(student)
# Out:
# {'name': 'jane', 'age': 26, 'courses': ['Math', 'statistics'], 'phone': '123-456'}

# %%
student['phone']='123-456'
student.update({'age':26})
print(student)
# Out:
# {'name': 'jane', 'age': 26, 'courses': ['Math', 'statistics'], 'phone': '123-456'}

# %%
#Q11
name="Mahesh"
l=[]
for i in name:
    l.append(i.capitalize())
print(l)
# Out:
# ['M', 'A', 'H', 'E', 'S', 'H']

# %%
#Q12
a=np.array([range(i,i+4) for i in [1,3,5]])
print(a)
# Out:
# [[1 2 3 4]
#  [3 4 5 6]
#  [5 6 7 8]]
